# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.patches import Ellipse
import matplotlib.patches as patches
import librosa

# %run graphing_function_recent.ipynb

# %%
#Use this for all adjustable values 
#input file paths here (include .csv):
video_path = r'\\10.25.16.5\yaochen\Active\DLC\Final_Models\Lindsey\escape_behavior_2-lindsey_christinger-2024-06-13_v1\V3_Tested2\coords_csv\CoordV3_M8_P2_6_22_24_videoDLC_resnet50_escape_behavior_2Jun13shuffle1_1030000_filtered_day.csv'
time_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V3_updated\Timestamp\M8_P2_6_22_24_timestamp0.csv'
audio_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V3_updated\Audio\M8_P2_6_22_24_audio.wav'

#input coordinates for the shelter and platform 
north_pixel = 26
south_pixel = 462
east_pixel = 570
west_pixel = 101
shelter_x_pixel = 143
shelter_y_pixel = 259

#input info from time_and_audio info notebook (either from audacity or bonsai)
stimulus_start = 399.294 #stimulus start time
stimulus_end = 406.960 #stimulus end time
escape_done = 404 #time mouse reaches shelter location

# %%
#manually decide?
escape_response = True
freezing_response = False

# %%
#read in DLC data, convert to cm, center platform at 0,0
shelter_x, shelter_y, x_diam, y_diam, coord_scaled = single_mouse_data(north_pixel, south_pixel, east_pixel, west_pixel, shelter_x_pixel, shelter_y_pixel, video_path)

# %%
#replace any head, nose, or center points with likelihood < .9 with NA
filter_data(.8, coord_scaled)

# %%
#coord_filtered

# %%
coord_scaled
# Out:
#        Unnamed: 0  frames     nose_x   nose_y  nose_likelihood     head_x  \
# 0               0       0        NaN      NaN         0.232153  -3.530648
# 1               1       1        NaN      NaN         0.215648  -3.520987
# 2               2       2        NaN      NaN         0.172951  -3.485705
# 3               3       3        NaN      NaN         0.172518  -3.481267
# 4               4       4        NaN      NaN         0.208827  -3.458686
# ...           ...     ...        ...      ...              ...        ...
# 14723       14723   14723 -29.776141  1.89856         0.000205 -30.769178
# 14724       14724   14724 -29.776141  1.89856         0.000385 -30.769178
# 14725       14725   14725 -29.776141  1.89856         0.000240 -30.769178
# 14726       14726   14726 -29.776141  1.89856         0.000273 -30.769178
# 14727       14727   14727 -29.776141  1.89856         0.000273 -30.769178
#
#           head_y  head_likelihood  earRight_x  earRight_y  ...  \
# 0     -31.244804         0.998167   -2.941999  -31.853875  ...
# 1     -31.228078         0.999016   -2.922006  -31.852718  ...
# 2     -31.228078         0.998784   -2.881785  -31.844564  ...
# 3     -31.228078         0.998047   -2.856370  -31.844564  ...
# 4     -31.215375         0.999094   -2.841644  -31.831131  ...
# ...          ...              ...         ...         ...  ...
# 14723   3.693479         0.008219  -29.740663   -0.281725  ...
# 14724   3.693479         0.007667  -29.740663   -0.222915  ...
# 14725   3.693479         0.008883  -29.745028   -0.115403  ...
# 14726   3.693479         0.009445  -29.745028   -0.115403  ...
# 14727   3.693479         0.007758  -29.745028   -0.222915  ...
#
#        spine1_likelihood   center_x   center_y  center_likelihood   spine2_x  \
# 0               0.999914  -1.370673 -29.498407           0.999990  -0.053759
# 1               0.999935  -1.340939 -29.485669           0.999991  -0.022720
# 2               0.999942  -1.340939 -29.461389           0.999991  -0.022720
# 3               0.999935  -1.340939 -29.450622           0.999991  -0.021267
# 4               0.999928  -1.340939 -29.448727           0.999991  -0.017715
# ...                  ...        ...        ...                ...        ...
# 14723           0.000016 -29.647781   4.796132           0.000336  23.651907
# 14724           0.000018 -29.647781   4.796132           0.000333  23.651907
# 14725           0.000021 -29.647781   4.796132           0.000291  23.649343
# 14726           0.000024 -29.647781   4.796132           0.000275  23.644079
# 14727           0.000020 -29.647781   4.796132           0.000259 -28.911732
#
#         spine2_y  spine2_likelihood   spine3_x   spine3_y  spine3_likelihood
# 0     -28.250923           0.999994   1.207629 -26.635771           0.999997
# 1     -28.245882           0.999995   1.222045 -26.624842           0.999997
# 2     -28.227349           0.999994   1.226788 -26.602338           0.999996
# 3     -28.219662           0.999994   1.236092 -26.602338           0.999997
# 4     -28.209121           0.999994   1.244935 -26.590409           0.999996
# ...          ...                ...        ...        ...                ...
# 14723 -33.210070           0.000032 -29.482748   0.950486           0.001462
# 14724 -33.210070           0.000039 -29.474290   1.101641           0.004309
# 14725 -33.193667           0.000036 -29.452521   1.122018           0.007893
# 14726 -33.193667           0.000046 -29.474290   1.122018           0.004018
# 14727 -33.193667           0.000035 -29.474290   1.101641           0.006035
#
# [14728 rows x 26 columns]

# %%
#convert timestamps to zeroed seconds
convert_time(time_path, coord_scaled)

# %%
#REPLACE ONCE WE HAVE STIMULUS TIMESTAMPS
#returns start and stop times of stimulus.
start, stimulus_end = audio_timing(stimulus_start, stimulus_end, audio_path, coord_scaled['time'].iloc[-1])

# %%
#find time stimulus ends and mouse reaches shelter(escape) if stimulus is set to 0s
end, escape = time_set_zero(start, stimulus_end, escape_done, coord_scaled)

# %%
#calculate displacement as 'displacement'
displacement(shelter_x, shelter_y, coord_scaled)

# %%
#calculate speed as 'speed' and change in displacement as 'delta_vector'
total_distance = speed(coord_scaled)

# %%
#calculate head angle as 'head_angle'
angle(shelter_x, shelter_y, coord_scaled)

# %%
#calculate head angle speed as 'angle_speed'
angle_speed(coord_scaled)

# %%
#create dataframes isolated to 4 ranges: just shelter reaching, 3 seconds before and 6 after, 2 before and 4 after, and 1 where you can input your own parameters
#return 4 dataframes 
escape_only, four_second, six_second, long_range = dataframe_ranges(-15, 30, escape,coord_scaled)

# %%
trajectory(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_trajectory_figure(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
angle_speed_figure(four_second['time_set'].iloc[-1], 4,four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ratio, initial_displacement, total_distance = linearity_ratio(escape_only)

# %%
likelihood_data, likelihood_minus_nose, likelihood_center = likelihood_check(0, 8, .9, coord_scaled)

# %%
likelihood_data #need to adjust time frame to be useful
# Out:
#        Unnamed: 0  frames     nose_x     nose_y  nose_likelihood     head_x  \
# 9968         9968    9968   7.202585 -30.427480         0.178096   6.535099
# 9969         9969    9969   7.426361 -30.398212         0.438073   6.535099
# 9971         9971    9971   7.467092 -30.017799         0.894509   6.460025
# 10098       10098   10098 -26.119453  -1.438919         0.840871 -25.210616
# 10099       10099   10099 -26.150094  -1.480048         0.358898 -25.885002
# ...           ...     ...        ...        ...              ...        ...
# 10163       10163   10163 -28.111146  -4.112366         0.005596 -30.027192
# 10164       10164   10164 -28.141787  -4.153496         0.004838 -29.994502
# 10165       10165   10165 -28.172429  -4.194626         0.009054 -29.994502
# 10166       10166   10166 -28.203070  -4.235756         0.008197 -30.027192
# 10167       10167   10167 -28.233712  -4.276886         0.004962 -30.036313
#
#           head_y  head_likelihood  earRight_x  earRight_y  ...   spine3_x  \
# 9968  -30.801394         0.998360    6.897363  -30.107974  ...   0.668618
# 9969  -30.687864         0.999723    6.897363  -29.963171  ...   1.182507
# 9971  -30.183754         0.999952    6.775873  -29.421316  ...   1.182507
# 10098  -1.132519         0.999997  -25.008016   -1.906350  ... -18.942179
# 10099  -1.423283         0.999996  -25.666737   -2.321039  ... -19.545874
# ...          ...              ...         ...         ...  ...        ...
# 10163  -3.288918         0.999593  -29.912685   -4.048439  ... -24.124752
# 10164  -3.288918         0.999444  -29.904511   -4.049031  ... -24.113239
# 10165  -3.304378         0.999602  -29.904511   -4.052769  ... -24.113239
# 10166  -3.295519         0.999759  -29.958759   -4.049031  ... -24.132698
# 10167  -3.295519         0.999617  -29.958759   -4.049031  ... -24.132698
#
#         spine3_y  spine3_likelihood        time  time_set  displacement  \
# 9968  -27.897606           1.000000  398.819315  0.018678     43.122936
# 9969  -27.736141           0.999998  398.859226  0.058589     43.059763
# 9971  -27.619872           1.000000  398.939072  0.138435     42.777466
# 10098  -0.563168           0.999999  404.020813  5.220176      3.993497
# 10099  -0.639147           0.999997  404.060480  5.259843      3.998769
# ...          ...                ...         ...       ...           ...
# 10163  -1.781004           1.000000  406.622579  7.821942      5.744470
# 10164  -1.780483           1.000000  406.660954  7.860317      5.738682
# 10165  -1.781004           1.000000  406.701517  7.900880      5.744509
# 10166  -1.776730           1.000000  406.741069  7.940432      5.764068
# 10167  -1.778254           1.000000  406.780954  7.980317      5.767709
#
#            speed  delta_vector  head_angle  angle_speed
# 9968   10.170798      0.406303    1.824978    -1.048550
# 9969    2.145268      0.085620    2.023109     4.964323
# 9971    1.223917      0.048752    2.180564    -4.145958
# 10098  16.197343      0.656802    1.949547     1.131271
# 10099  18.895851      0.749542    2.017943     1.724239
# ...          ...           ...         ...          ...
# 10163   0.269169      0.011063    1.229598     0.578599
# 10164   0.423288      0.016244    1.263593     0.885847
# 10165   0.156732      0.006358    1.282881     0.475524
# 10166   0.628202      0.024847    1.300238     0.438828
# 10167   0.226551      0.009036    1.321946     0.544274
#
# [73 rows x 33 columns]

# %%
rotate, shelter_rotate_x, shelter_rotate_y = rotate_trajectory(shelter_x, shelter_y, escape_only)
normalized_df, shelter_normalized_x, shelter_normalized_y, combined_range = normalize_rotation(rotate, shelter_rotate_x, shelter_rotate_y)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
    #make x and y scales equal - present as a circle


    #plot the center x and y coordinates
x = rotate['rotated_x']
y = rotate['rotated_y']

ax.text(shelter_rotate_x,shelter_rotate_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_rotate_x - 5.25), (shelter_rotate_y-6.25)), 10.5,12.5,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
x = normalized_df['x']
y = normalized_df['y']

ax.text(shelter_normalized_x,shelter_normalized_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_normalized_x - 5.25/combined_range), (shelter_normalized_y-6.25/combined_range)), 10.5/combined_range,12.5/combined_range,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)
