# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.patches import Ellipse
import matplotlib.patches as patches
import librosa

# %run graphing_function_recent.ipynb

# %%
#Use this for all adjustable values 
#input file paths here (include .csv):
video_path = r'\\10.25.16.5\yaochen\Active\DLC\Final_Models\Lindsey\escape_behavior_2-lindsey_christinger-2024-06-13_v1\V3_Tested2\coords_csv\CoordV3_M3_P2_6_21_24_videoDLC_resnet50_escape_behavior_2Jun13shuffle1_1030000_filtered_day.csv'
time_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V3_updated\Timestamp\M3_P2_6_21_24_timestamp0.csv'
audio_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V3_updated\Audio\M3_P2_6_21_24_audio.wav'

#input coordinates for the shelter and platform 
north_pixel = 26
south_pixel = 462
east_pixel = 570
west_pixel = 101
shelter_x_pixel = 531
shelter_y_pixel = 248

#input info from time_and_audio info notebook (either from audacity or bonsai)
stimulus_start = 1164.262 #stimulus start time
stimulus_end = 1178.796 #stimulus end time
escape_done = 1165 #time mouse reaches shelter location

# %%
#manually decide?
escape_response = False
freezing_response = False

# %%
#read in DLC data, convert to cm, center platform at 0,0
shelter_x, shelter_y, x_diam, y_diam, coord_scaled = single_mouse_data(north_pixel, south_pixel, east_pixel, west_pixel, shelter_x_pixel, shelter_y_pixel, video_path)

# %%
#replace any head, nose, or center points with likelihood < .9 with NA
filter_data(.8, coord_scaled)

# %%
#coord_filtered

# %%
coord_scaled
# Out:
#        Unnamed: 0  frames     nose_x    nose_y  nose_likelihood     head_x  \
# 0               0       0        NaN       NaN         0.000136   8.052562
# 1               1       1        NaN       NaN         0.000189   8.052562
# 2               2       2        NaN       NaN         0.000202   8.052562
# 3               3       3        NaN       NaN         0.000470   7.828566
# 4               4       4        NaN       NaN         0.000533   7.753524
# ...           ...     ...        ...       ...              ...        ...
# 31778       31778   31778  20.124854  4.779096         0.999591  20.850891
# 31779       31779   31779  20.115999  5.093134         0.999390  20.842822
# 31780       31780   31780  20.115999  5.229507         0.998966  20.840655
# 31781       31781   31781  20.023548  5.229507         0.999448  20.776571
# 31782       31782   31782  19.835608  5.229507         0.998971  20.729988
#
#           head_y  head_likelihood  earRight_x  earRight_y  ...  \
# 0     -29.993966         0.992118    8.704101  -29.592020  ...
# 1     -29.993966         0.990229    8.704101  -29.592020  ...
# 2     -29.993966         0.988817    8.704101  -29.592020  ...
# 3     -30.116879         0.941258    8.565582  -29.819399  ...
# 4     -30.249310         0.986852    8.402252  -29.854743  ...
# ...          ...              ...         ...         ...  ...
# 31778   3.293083         0.999991   20.027636    3.165245  ...
# 31779   3.661375         0.999990   20.019888    3.524930  ...
# 31780   3.800105         0.999989   20.009576    3.653587  ...
# 31781   3.800105         0.999981   19.961830    3.653587  ...
# 31782   3.800105         0.999988   19.904050    3.653587  ...
#
#        spine1_likelihood   center_x   center_y  center_likelihood   spine2_x  \
# 0               0.999975   6.734331 -28.304825           0.999998   5.658485
# 1               0.999970   6.734331 -28.304825           0.999998   5.677934
# 2               0.999983   6.734331 -28.304825           0.999998   5.677934
# 3               0.999976   6.733128 -28.391696           0.999997   5.674803
# 4               0.999992   6.642352 -28.425914           0.999997   5.660736
# ...                  ...        ...        ...                ...        ...
# 31778           0.999996  20.721006   0.118577           0.999996  20.212809
# 31779           0.999995  20.730306   0.368615           0.999995  20.248298
# 31780           0.999997  20.759797   0.500242           0.999997  20.303887
# 31781           0.999997  20.759797   0.500242           0.999999  20.303887
# 31782           0.999992  20.730306   0.500242           0.999998  20.303887
#
#         spine2_y  spine2_likelihood   spine3_x   spine3_y  spine3_likelihood
# 0     -27.389368           0.999994   4.122093 -26.313924           0.999996
# 1     -27.389368           0.999996   4.156526 -26.313178           0.999997
# 2     -27.388338           0.999995   4.157645 -26.304451           0.999996
# 3     -27.388338           0.999994   4.175812 -26.297254           0.999996
# 4     -27.388401           0.999995   4.182830 -26.228404           0.999997
# ...          ...                ...        ...        ...                ...
# 31778  -1.481583           0.999982  19.273270  -2.991295           0.999999
# 31779  -1.325215           0.999985  19.340684  -2.859830           0.999999
# 31780  -1.082814           0.999985  19.433969  -2.740843           0.999999
# 31781  -1.082814           0.999985  19.433969  -2.740843           0.999999
# 31782  -1.082814           0.999989  19.433969  -2.740843           0.999999
#
# [31783 rows x 26 columns]

# %%
#convert timestamps to zeroed seconds
convert_time(time_path, coord_scaled)

# %%
#REPLACE ONCE WE HAVE STIMULUS TIMESTAMPS
#returns start and stop times of stimulus.
start, stimulus_end = audio_timing(stimulus_start, stimulus_end, audio_path, coord_scaled['time'].iloc[-1])

# %%
#find time stimulus ends and mouse reaches shelter(escape) if stimulus is set to 0s
end, escape = time_set_zero(start, stimulus_end, escape_done, coord_scaled)

# %%
#calculate displacement as 'displacement'
displacement(shelter_x, shelter_y, coord_scaled)

# %%
#calculate speed as 'speed' and change in displacement as 'delta_vector'
total_distance = speed(coord_scaled)

# %%
#calculate head angle as 'head_angle'
angle(shelter_x, shelter_y, coord_scaled)

# %%
#calculate head angle speed as 'angle_speed'
angle_speed(coord_scaled)

# %%
#create dataframes isolated to 4 ranges: just shelter reaching, 3 seconds before and 6 after, 2 before and 4 after, and 1 where you can input your own parameters
#return 4 dataframes 
escape_only, four_second, six_second, long_range = dataframe_ranges(-15, 30, escape,coord_scaled)

# %%
trajectory(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_trajectory_figure(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
print(shelter_x)
# Out:
# 25.427505330490405

# %%
displacement_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
angle_speed_figure(four_second['time_set'].iloc[-1], 4,four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ratio, initial_displacement, total_distance = linearity_ratio(escape_only)

# %%
likelihood_data, likelihood_minus_nose, likelihood_center = likelihood_check(0, 8, .9, coord_scaled)

# %%
likelihood_data #need to adjust time frame to be useful
# Out:
#        Unnamed: 0  frames     nose_x     nose_y  nose_likelihood     head_x  \
# 29088       29088   29088   9.100728  24.132122         0.223127   9.421008
# 29089       29089   29089   9.352030  24.538721         0.486476   9.421251
# 29091       29091   29091  10.539850  24.109911         0.171620  10.010654
# 29092       29092   29092  11.476369  23.274502         0.183715  10.694745
# 29093       29093   29093  12.412888  22.439093         0.815840  11.357853
# ...           ...     ...        ...        ...              ...        ...
# 29259       29259   29259 -26.134467  11.006211         0.003596 -26.944903
# 29260       29260   29260 -26.030093  11.296883         0.001882 -26.904357
# 29261       29261   29261 -25.925720  11.587554         0.002775 -26.904357
# 29262       29262   29262 -25.821346  11.878226         0.353169 -26.836454
# 29263       29263   29263 -25.716972  12.168897         0.857423 -26.672635
#
#           head_y  head_likelihood  earRight_x  earRight_y  ...   spine3_x  \
# 29088  24.153234         0.999950    8.590898   24.135707  ...   8.094350
# 29089  24.696092         0.999987    8.596967   24.750598  ...   8.094350
# 29091  24.696092         0.999920    9.373080   24.750598  ...   8.246344
# 29092  23.892618         0.999955   10.274144   24.509281  ...   8.246344
# 29093  22.950804         0.999938   11.065844   23.800492  ...   8.140842
# ...          ...              ...         ...         ...  ...        ...
# 29259   9.356856         0.999965  -27.203218    8.526620  ... -21.585200
# 29260   9.544345         0.999820  -27.277648    8.715305  ... -21.585200
# 29261   9.768951         0.994431  -27.399975    9.008844  ... -21.711468
# 29262  10.755097         0.984350  -27.399975   10.452015  ... -22.378407
# 29263  11.467704         0.998538  -27.399975   11.382280  ... -23.166505
#
#         spine3_y  spine3_likelihood         time  time_set  displacement  \
# 29088  17.979155           0.999999  1163.808652  0.001158     26.680291
# 29089  18.825171           0.999997  1163.849075  0.041581     27.151008
# 29091  18.825171           0.999999  1163.928601  0.121107     27.128629
# 29092  18.785600           0.999997  1163.968742  0.161248     27.093211
# 29093  18.785600           0.999996  1164.008652  0.201158     26.721586
# ...          ...                ...          ...       ...           ...
# 29259   8.457323           1.000000  1170.650329  6.842835     50.524743
# 29260   8.452208           1.000000  1170.690355  6.882861     50.536840
# 29261   8.261487           0.999999  1170.730393  6.922899     50.764773
# 29262   7.751890           0.999999  1170.771200  6.963706     51.318363
# 29263   7.186484           0.999999  1170.810316  7.002822     51.772787
#
#            speed  delta_vector  head_angle  angle_speed
# 29088  16.072975      0.644141    2.101072    -5.462196
# 29089  14.860529      0.600707    0.999958   -27.239792
# 29091   0.000000      0.000000    0.165936   -51.967416
# 29092   1.439826      0.057796    0.338487     4.298620
# 29093   9.776950      0.390198    0.558197     5.505133
# ...          ...           ...         ...          ...
# 29259   0.000000      0.000000    1.280501    -1.228819
# 29260   0.305730      0.012237    1.278094    -0.060144
# 29261   5.798290      0.232152    1.251311    -0.668942
# 29262  13.694644      0.558837    1.028531    -5.459358
# 29263  14.314833      0.559939    0.839389    -4.835395
#
# [66 rows x 33 columns]

# %%
rotate, shelter_rotate_x, shelter_rotate_y = rotate_trajectory(shelter_x, shelter_y, escape_only)
normalized_df, shelter_normalized_x, shelter_normalized_y, combined_range = normalize_rotation(rotate, shelter_rotate_x, shelter_rotate_y)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
    #make x and y scales equal - present as a circle


    #plot the center x and y coordinates
x = rotate['rotated_x']
y = rotate['rotated_y']

ax.text(shelter_rotate_x,shelter_rotate_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_rotate_x - 5.25), (shelter_rotate_y-6.25)), 10.5,12.5,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.plot()

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
x = normalized_df['x']
y = normalized_df['y']

ax.text(shelter_normalized_x,shelter_normalized_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_normalized_x - 5.25/combined_range), (shelter_normalized_y-6.25/combined_range)), 10.5/combined_range,12.5/combined_range,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)
