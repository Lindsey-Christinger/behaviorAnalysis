# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.patches import Ellipse
import matplotlib.patches as patches
import librosa

# %run graphing_function_recent_V2.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/magics/execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'graphing_function_recent_V2.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 import matplotlib.patches as patches
#       7 import librosa
# ----> 9 get_ipython().run_line_magic('run', 'graphing_function_recent_V2.ipynb')
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/lib/python3.12/site-packages/IPython/core/magics/execution.py:727, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     725     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     726         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 727     raise Exception(msg) from e
#     728 except TypeError:
#     729     if fpath in sys.meta_path:
#
# Exception: File `'graphing_function_recent_V2.ipynb'` not found.

# %%
#Use this for all adjustable values 
#input file paths here (include .csv):
video_path = r'\\10.25.16.5\yaochen\Active\DLC\Final_Models\Hanna\escape_behavior_HannaJachna_2024-07-8\Tested_V2\coords_csv\CoordM2_P2_6_17_24_videoDLC_resnet50_escape_behavior_2Jun13shuffle1_1030000_filtered_day.csv'
time_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V2\Timestamp\M2_P2_6_17_24_timestamp0.csv'
audio_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V2\Audio\M2_P2_6_17_24_audio.wav'

north_pixel = 26
south_pixel = 462
east_pixel = 570
west_pixel = 101
shelter_x_pixel = 117
shelter_y_pixel = 250

#input info from time_and_audio info notebook (either from audacity or bonsai)
stimulus_start = 300.00890099999395  #stimulus start time
stimulus_end = 307.51190099999394 #stimulus end time
escape_done = 301 #time mouse reaches shelter location

# %%
#manually decide?
escape_response = True
freezing_response = False
#small_angle =

# %%
#read in DLC data, convert to cm, center platform at 0,0
shelter_x, shelter_y, x_diam, y_diam, coord_scaled = single_mouse_data(north_pixel, south_pixel, east_pixel, west_pixel, shelter_x_pixel, shelter_y_pixel, video_path)

# %%
#replace any head, nose, or center points with likelihood < .9 with NA
filter_data(.8, coord_scaled)

# %%
#coord_filtered

# %%
coord_scaled
# Out:
#        Unnamed: 0  frames     nose_x    nose_y  nose_likelihood     head_x  \
# 0               0       0        NaN       NaN         0.005229  -4.264477
# 1               1       1        NaN       NaN         0.007342  -4.264477
# 2               2       2        NaN       NaN         0.004980  -4.264477
# 3               3       3        NaN       NaN         0.002566  -4.352455
# 4               4       4        NaN       NaN         0.003195  -4.440433
# ...           ...     ...        ...       ...              ...        ...
# 10262       10262   10262  29.414422  1.205251         0.023898  28.672381
# 10263       10263   10263  29.414422  1.205251         0.009034  28.672381
# 10264       10264   10264  29.414422  1.205251         0.012058  28.672381
# 10265       10265   10265  29.414422  1.205251         0.003960  28.671428
# 10266       10266   10266  29.414422  1.205251         0.014774  28.653820
#
#           head_y  head_likelihood  earRight_x  earRight_y  ...  \
# 0      30.722261         0.899917   -5.113485   30.628884  ...
# 1      30.753853         0.934138   -5.113485   30.630284  ...
# 2      30.753853         0.892546   -5.113485   30.630284  ...
# 3      30.755704         0.783134   -5.156496   30.628884  ...
# 4      30.757555         0.865879   -5.281618   30.591922  ...
# ...          ...              ...         ...         ...  ...
# 10262  -6.334743         0.999977   29.625918   -6.131823  ...
# 10263  -6.692329         0.999942   29.626157   -6.468505  ...
# 10264  -7.136049         0.999794   29.626157   -6.873222  ...
# 10265  -7.522641         0.999847   29.626157   -7.244449  ...
# 10266  -7.962585         0.999961   29.552988   -7.695836  ...
#
#        spine1_likelihood   center_x   center_y  center_likelihood   spine2_x  \
# 0               0.999972  -4.939990  27.454775           0.999983  -6.334236
# 1               0.999974  -4.917071  27.464262           0.999987  -6.324801
# 2               0.999971  -4.914936  27.472750           0.999984  -6.313354
# 3               0.999962  -4.883698  27.481089           0.999984  -6.207117
# 4               0.999974  -4.883698  27.481089           0.999985  -6.207117
# ...                  ...        ...        ...                ...        ...
# 10262           0.999983  27.388269  -3.758879           0.999998  26.390577
# 10263           0.999988  27.388269  -4.098591           0.999998  26.390577
# 10264           0.999987  27.388269  -4.303658           0.999998  26.381226
# 10265           0.999972  27.243590  -4.805077           0.999995  26.036601
# 10266           0.999995  27.028188  -5.392514           0.999988  26.029027
#
#         spine2_y  spine2_likelihood   spine3_x   spine3_y  spine3_likelihood
# 0      26.017795           0.999968  -7.807414  24.807701           0.999999
# 1      26.040441           0.999971  -7.774986  24.820659           0.999999
# 2      26.044199           0.999965  -7.756802  24.820659           0.999999
# 3      26.088889           0.999971  -7.756802  24.807701           0.999999
# 4      26.088889           0.999970  -7.774986  24.801168           0.999999
# ...          ...                ...        ...        ...                ...
# 10262  -2.089141           0.999993  25.185056  -0.352894           0.999999
# 10263  -2.691763           0.999989  25.185056  -0.962670           0.999998
# 10264  -3.078827           0.999972  24.889737  -1.580159           0.999994
# 10265  -3.465912           0.999918  24.676954  -1.890156           0.999997
# 10266  -3.722370           0.999951  24.611383  -2.093598           0.999999
#
# [10267 rows x 26 columns]

# %%
#convert timestamps to zeroed seconds
convert_time(time_path, coord_scaled)

# %%
#REPLACE ONCE WE HAVE STIMULUS TIMESTAMPS
#returns start and stop times of stimulus.
start, stimulus_end = audio_timing(stimulus_start, stimulus_end, audio_path, coord_scaled['time'].iloc[-1])

# %%
#find time stimulus ends and mouse reaches shelter(escape) if stimulus is set to 0s
end, escape = time_set_zero(start, stimulus_end, escape_done, coord_scaled)

# %%
#calculate displacement as 'displacement'
displacement(shelter_x, shelter_y, coord_scaled)

# %%
#calculate speed as 'speed' and change in displacement as 'delta_vector'
total_distance = speed(coord_scaled)

# %%
#calculate head angle as 'head_angle'
angle(shelter_x, shelter_y, coord_scaled)

# %%
#calculate head angle speed as 'angle_speed'
angle_speed(coord_scaled)

# %%
#create dataframes isolated to 4 ranges: just shelter reaching, 3 seconds before and 6 after, 2 before and 4 after, and 1 where you can input your own parameters
#return 4 dataframes 
escape_only, four_second, six_second, long_range = dataframe_ranges(-15, 30, escape,coord_scaled)

# %%
trajectory(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_trajectory_figure(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
angle_speed_figure(four_second['time_set'].iloc[-1], 4,four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ratio, initial_displacement, total_distance = linearity_ratio(escape_only)

# %%
#shelter_rotation(shelter_x, shelter_y, escape_only)

# %%
escape_only
# Out:
#       Unnamed: 0  frames     nose_x     nose_y  nose_likelihood     head_x  \
# 7487        7487    7487  12.878960 -11.408895         0.999963  11.447479
# 7488        7488    7488  13.363064 -10.791438         0.999945  11.857894
# 7489        7489    7489  13.670128 -10.535489         0.999923  12.068879
# 7490        7490    7490  13.670128 -10.441644         0.999928  12.068879
# 7491        7491    7491  13.670128 -10.441644         0.999965  12.068879
# 7492        7492    7492  13.381902 -10.441644         0.999982  11.814288
# 7493        7493    7493  12.860948 -10.635030         0.999963  11.496423
# 7494        7494    7494  11.967064 -10.661796         0.999896  10.718929
# 7495        7495    7495  11.204224 -10.681083         0.999922  10.150792
# 7496        7496    7496  10.430858 -10.839767         0.999913   9.289845
# 7497        7497    7497   9.340858 -10.977811         0.999975   8.498097
# 7498        7498    7498   8.526346 -11.051550         0.999871   7.902989
# 7499        7499    7499   7.381868 -11.051550         0.999955   7.010308
# 7500        7500    7500   5.383147 -11.338542         0.999942   5.759641
# 7501        7501    7501   3.547438 -11.338542         0.999975   4.581270
# 7502        7502    7502   1.322534 -11.338542         0.999979   2.918469
# 7503        7503    7503  -0.448964 -10.811659         0.999990   1.252398
# 7504        7504    7504  -2.254697 -10.098891         0.999953  -0.562504
# 7505        7505    7505  -4.603656  -9.057471         0.999988  -2.794097
# 7506        7506    7506  -6.270387  -7.777209         0.999952  -4.731835
# 7507        7507    7507  -7.989880  -6.275629         0.999981  -6.509783
# 7508        7508    7508  -9.818484  -4.713642         0.999997  -8.204521
# 7509        7509    7509 -11.593872  -3.266820         0.999980 -10.255203
# 7510        7510    7510 -13.116257  -1.635630         0.999974 -11.925889
# 7511        7511    7511 -14.540983  -0.002780         0.999976 -13.198166
# 7512        7512    7512 -15.945891   1.690718         0.999990 -14.650770
# 7513        7513    7513 -17.442331   3.078165         0.999980 -16.288472
# 7514        7514    7514 -18.820879   4.376462         0.999976 -17.640525
# 7515        7515    7515 -20.057592   6.059682         0.999985 -18.925313
# 7516        7516    7516 -21.153546   7.473124         0.999912 -20.070242
# 7517        7517    7517 -23.051683   7.878861         0.999634 -21.572340
# 7518        7518    7518 -24.730039   8.148819         0.997343 -23.313654
# 7519        7519    7519 -26.511216   8.840103         0.999619 -25.123099
#
#          head_y  head_likelihood  earRight_x  earRight_y  ...   spine3_x  \
# 7487 -12.430036         0.999995   10.928648  -11.739406  ...   3.689231
# 7488 -11.878520         0.999990   11.304745  -11.373869  ...   4.339468
# 7489 -11.607407         0.999994   11.523752  -10.990883  ...   4.667275
# 7490 -11.607407         0.999996   11.523752  -10.990883  ...   4.667275
# 7491 -11.607407         0.999995   11.523752  -10.990883  ...   4.667275
# 7492 -11.779566         0.999993   11.270054  -11.133355  ...   4.400011
# 7564  11.547696           0.999999  302.634522  3.113720     12.837998
# 7674  -3.099200           0.999992  307.035431  7.514629      3.987473
# 7675  -2.916731           0.999992  307.075879  7.555077      4.072207
#
#           speed  delta_vector  head_angle  angle_speed
# 7521  44.915859      1.790885    1.209136    19.937780
# 7522  44.658527      1.786341    1.325150     2.900332
# 7523  32.616955      1.306766    1.441730     2.909859
# 7524  18.697688      0.747197    1.555106     2.837076
# 7525   0.000000      0.000000    1.662064     2.661195
# 7526   0.049168      0.001998    1.760383     2.419266
# 7527   2.216441      0.087040    1.848923     2.254639
# 7528   4.759299      0.190129    1.927462     1.965987
# 7529  10.140095      0.404955    1.996418     1.726670
# 7530  11.904194      0.477239    2.056575     1.500538
# 7531  12.036437      0.483768    2.108872     1.301181
# 7532   9.868546      0.394229    2.154272     1.136465
# 7533   4.520175      0.180174    2.193681     0.988707
# 7534   5.427414      0.217026    2.344848     3.780397
# 7547   7.760464      0.307539    1.916654   -14.701683
# 7548   2.009888      0.080189    1.709109    -5.202034
# 7549   0.560362      0.022407    1.464931    -6.106422
# 7550   1.776564      0.071176    1.206966    -6.438825
# 7551   0.131355      0.005311    0.966531    -5.946067
# 7552   1.768003      0.070108    0.764329    -5.099160
# 7553   0.765713      0.030550    0.604026    -4.017823
# 7554   0.641250      0.025633    0.479566    -3.113507
# 7555   0.137593      0.005553    0.382743    -2.399117
# 7556   3.071530      0.122235    0.306450    -1.917112
# 7557   0.909666      0.036433    0.245320    -1.526290
# 7558   0.312218      0.012576    0.195484    -1.237206
# 7559   4.219625      0.167760    0.154178    -1.038970
# 7560  11.944122      0.476236    0.119416    -0.871841
# 7561   4.357027      0.174338    0.089754    -0.741302
# 7562   9.326726      0.377005    0.064126    -0.634001
# 7563   5.639664      0.223929    0.020033    -1.110498
# 7564   1.191492      0.047736    0.062835     1.068327
# 7674   5.176846      0.206675    2.715673     2.636540
# 7675   2.384435      0.096446    2.819954     2.578154
#
# [34 rows x 33 columns]

# %%
rotate, shelter_rotate_x, shelter_rotate_y = rotate_trajectory(shelter_x, shelter_y, escape_only)
normalized_df, shelter_normalized_x, shelter_normalized_y, combined_range = normalize_rotation(rotate, shelter_rotate_x, shelter_rotate_y)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
    #make x and y scales equal - present as a circle


    #plot the center x and y coordinates
x = rotate['rotated_x']
y = rotate['rotated_y']

ax.text(shelter_rotate_x,shelter_rotate_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_rotate_x - 5.25), (shelter_rotate_y-6.25)), 10.5,12.5,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
x = normalized_df['x']
y = normalized_df['y']

ax.text(shelter_normalized_x,shelter_normalized_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_normalized_x - 5.25/combined_range), (shelter_normalized_y-6.25/combined_range)), 10.5/combined_range,12.5/combined_range,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)
