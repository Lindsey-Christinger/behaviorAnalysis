# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.patches import Ellipse
import matplotlib.patches as patches
import librosa

# %run graphing_function_recent.ipynb

# %%
#Use this for all adjustable values 
#input file paths here (include .csv):
video_path = r'\\10.25.16.5\yaochen\Active\DLC\Final_Models\Hanna\escape_behavior_HannaJachna_2024-07-8\Tested_V2\coords_csv\CoordM1_P2_6_17_24_videoDLC_resnet50_escape_behavior_2Jun13shuffle1_1030000_filtered_day.csv'
time_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V2\Timestamp\M1_P2_6_17_24_timestamp0.csv'
audio_path = r'\\10.25.16.5\yaochen\Active\Lindsey\set_up_testing\V2\Audio\M1_P2_6_17_24_audio.wav'

north_pixel = 26
south_pixel = 462
east_pixel = 570
west_pixel = 101
shelter_x_pixel = 526
shelter_y_pixel = 263

platform_center_x = west_pixel + ((east_pixel-west_pixel)/2)
platform_center_y = north_pixel + ((south_pixel-north_pixel)/2)

#input info from time_and_audio info notebook (either from audacity or bonsai)
stimulus_start = 77.61472700000087  #stimulus start time
stimulus_end = 85.22372700000088 #stimulus end time
escape_done = 78.5 #time mouse reaches shelter location

# %%
#manually decide?
escape_response = True
freezing_response = False
#small_angle =

# %%
#read in DLC data, convert to cm, center platform at 0,0
shelter_x, shelter_y, x_diam, y_diam, coord_scaled = single_mouse_data(north_pixel, south_pixel, east_pixel, west_pixel, shelter_x_pixel, shelter_y_pixel, video_path)

# %%
#replace any head, nose, or center points with likelihood < .9 with NA
filter_data(.8, coord_scaled)

# %%
#coord_filtered

# %%
coord_scaled
# Out:
#       Unnamed: 0  frames   nose_x    nose_y  nose_likelihood     head_x  \
# 0              0       0      NaN       NaN         0.002304        NaN
# 1              1       1      NaN       NaN         0.002186        NaN
# 2              2       2      NaN       NaN         0.002492        NaN
# 3              3       3      NaN       NaN         0.003733        NaN
# 4              4       4      NaN       NaN         0.003244        NaN
# ...          ...     ...      ...       ...              ...        ...
# 4397        4397    4397  28.7494  4.352305         0.003184  29.726991
# 4398        4398    4398  28.7494  4.352305         0.002695  29.726991
# 4399        4399    4399  28.7494  4.352305         0.003953  29.726991
# 4400        4400    4400  28.7494  4.352305         0.002491  29.726991
# 4401        4401    4401  28.7494  4.352305         0.002399  29.726991
#
#         head_y  head_likelihood  earRight_x  earRight_y  ...  \
# 0          NaN         0.007881  -32.256254  -33.758411  ...
# 1          NaN         0.007302  -32.048573  -33.735439  ...
# 2          NaN         0.007340   -0.631891  -33.735439  ...
# 3          NaN         0.009248   -0.631891  -33.735439  ...
# 4          NaN         0.009526   -0.631891  -33.735439  ...
# ...        ...              ...         ...         ...  ...
# 4397  5.655807         0.007111  -32.282949   -3.253922  ...
# 4398  5.655807         0.006290  -32.283041   -3.253922  ...
# 4399  5.655807         0.007301  -32.290666   -3.253922  ...
# 4400  5.655807         0.006297  -32.296084   -3.281369  ...
# 4401  5.655807         0.004897  -32.306263   -3.281369  ...
#
#       spine1_likelihood   center_x  center_y  center_likelihood  spine2_x  \
# 0              0.000154        NaN       NaN           0.000984 -0.368560
# 1              0.000132        NaN       NaN           0.000881 -0.366051
# 2              0.000176        NaN       NaN           0.001321 -0.284118
# 3              0.000254        NaN       NaN           0.001999 -0.284118
# 4              0.000198        NaN       NaN           0.001384 -0.284118
# ...                 ...        ...       ...                ...       ...
# 4397           0.000274  27.655811  4.507101           0.001534 -0.415928
# 4398           0.000259  27.655811  4.507101           0.001490 -0.415928
# 4399           0.000369  27.655811  4.507101           0.002234 -0.374259
# 4400           0.000268  27.655811  4.507101           0.001351 -0.374259
# 4401           0.000275  27.655811  4.507101           0.001519 -0.374259
#
#        spine2_y  spine2_likelihood   spine3_x  spine3_y  spine3_likelihood
# 0    -33.753230           0.000232 -31.801712 -2.779479           0.000429
# 1    -33.726802           0.000204 -31.801712 -2.682284           0.000533
# 2    -33.706370           0.000246 -31.801712 -2.682284           0.000499
# 3    -33.702073           0.000345 -31.806286 -2.682284           0.000381
# 4    -33.702073           0.000303 -31.830944 -2.682284           0.000419
# ...         ...                ...        ...       ...                ...
# 4397 -33.704013           0.000421 -31.862245 -2.473122           0.001070
# 4398 -33.712897           0.000386 -31.886856 -2.473122           0.001896
# 4399 -33.716621           0.000551 -31.886856 -2.473122           0.001672
# 4400 -33.759605           0.000392 -31.892843 -2.473122           0.001076
# 4401 -33.762054           0.000363 -31.916240 -2.473122           0.001036
#
# [4402 rows x 26 columns]

# %%
#convert timestamps to zeroed seconds
convert_time(time_path, coord_scaled)

# %%
#REPLACE ONCE WE HAVE STIMULUS TIMESTAMPS
#returns start and stop times of stimulus.
start, stimulus_end = audio_timing(stimulus_start, stimulus_end, audio_path, coord_scaled['time'].iloc[-1])

# %%
#find time stimulus ends and mouse reaches shelter(escape) if stimulus is set to 0s
end, escape = time_set_zero(start, stimulus_end, escape_done, coord_scaled)

# %%
#calculate displacement as 'displacement'
displacement(shelter_x, shelter_y, coord_scaled)

# %%
#calculate speed as 'speed' and change in displacement as 'delta_vector'
total_distance = speed(coord_scaled)

# %%
#calculate head angle as 'head_angle'
angle(shelter_x, shelter_y, coord_scaled)

# %%
#calculate head angle speed as 'angle_speed'
angle_speed(coord_scaled)

# %%
#create dataframes isolated to 4 ranges: just shelter reaching, 3 seconds before and 6 after, 2 before and 4 after, and 1 where you can input your own parameters
#return 4 dataframes 
escape_only, four_second, six_second, long_range = dataframe_ranges(-15, 30, escape,coord_scaled)

# %%
trajectory(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_trajectory_figure(shelter_x, shelter_y, x_diam, y_diam, escape_only)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
speed_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
displacement_figure(end,9, long_range)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(four_second['time_set'].iloc[-1],4, four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
head_angle_figure(six_second['time_set'].iloc[-1],4, six_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
angle_speed_figure(four_second['time_set'].iloc[-1], 4,four_second)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ratio, initial_displacement, total_distance = linearity_ratio(escape_only)

# %%
#shelter_rotation(shelter_x, shelter_y, escape_only)

# %%
escape_only
# Out:
#       Unnamed: 0  frames     nose_x     nose_y  nose_likelihood     head_x  \
# 1927        1927    1927  -5.216114  16.170851         0.999828  -3.610156
# 1928        1928    1928  -5.598232  16.450522         0.999861  -4.077812
# 1929        1929    1929  -6.228749  16.708832         0.999070  -4.589454
# 1930        1930    1930  -6.576550  17.169204         0.999635  -5.106197
# 1931        1931    1931  -7.006097  17.556548         0.999819  -5.514568
# 1932        1932    1932  -7.412106  17.926706         0.999960  -5.862952
# 1933        1933    1933  -7.996159  18.483696         0.999687  -6.581285
# 1966 -0.198834         0.999967   28.331899    0.629687  ...  21.482588
# 1967 -0.198834         0.999901   28.437846    0.632473  ...  21.490729
# 1968 -0.161519         0.999880   28.437846    0.698843  ...  21.490729
# ...        ...              ...         ...         ...  ...        ...
# 2122  8.313120         0.975740   27.412894    9.033834  ...  20.963804
# 2123  7.905132         0.933413   27.769181    8.697526  ...  21.137002
# 2124  7.832732         0.973157   27.810096    8.413107  ...  21.137002
# 2125  7.565908         0.994020   27.914677    8.335442  ...  21.150132
# 2126  7.279529         0.998361   28.244806    8.086900  ...  21.137002
#
#       spine3_y  spine3_likelihood       time  time_set  displacement  \
# 1964 -0.927599           0.999995  78.578356  1.490902      3.648406
# 1965 -0.963705           0.999996  78.618407  1.530953      3.418435
# 1966 -0.964403           0.999998  78.658829  1.571375      3.386458
# 1967 -1.011060           0.999998  78.698407  1.610953      3.403109
# 1968 -1.041411           0.999997  78.738381  1.650927      3.403109
# ...        ...                ...        ...       ...           ...
# 2122  6.441727           0.999999  84.899892  7.812438      4.860274
# 2123  6.612369           0.999999  84.940058  7.852604      4.770415
# 2124  6.622334           0.999999  84.981069  7.893615      4.585260
# 2125  6.622334           0.999999  85.020058  7.932604      4.562887
# 2126  6.655748           0.999999  85.059956  7.972502      4.547062
#
#           speed  delta_vector  head_angle  angle_speed
# 1964  16.045590      0.641422    3.069519    23.015579
# 1965  20.294478      0.812814    1.536421   -38.278635
# 1966  13.378892      0.540802    1.277582    -6.403416
# 1967   2.545535      0.100747    1.148234    -3.268194
# 1968   0.000000      0.000000    1.133344    -0.372492
# ...         ...           ...         ...          ...
# 2122  14.371315      0.575039    1.800346    -6.982528
# 2123   7.124634      0.286168    1.828594     0.703270
# 2124   4.521295      0.185423    1.824718    -0.094515
# 2125   0.574705      0.022407    1.854767     0.770721
# 2126   0.397238      0.015849    1.841176    -0.340656
#
# [74 rows x 33 columns]

# %%
rotate, shelter_rotate_x, shelter_rotate_y = rotate_trajectory(shelter_x, shelter_y, escape_only)
normalized_df, shelter_normalized_x, shelter_normalized_y, combined_range = normalize_rotation(rotate, shelter_rotate_x, shelter_rotate_y)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
    #make x and y scales equal - present as a circle


    #plot the center x and y coordinates
x = rotate['rotated_x']
y = rotate['rotated_y']

ax.text(shelter_rotate_x,shelter_rotate_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_rotate_x - 5.25), (shelter_rotate_y-6.25)), 10.5,12.5,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)

# %%
fig = plt.figure()  #create figure to fill in
ax = plt.axes()
    
x = normalized_df['x']
y = normalized_df['y']

ax.text(shelter_normalized_x,shelter_normalized_y, 'S', color = 'black', size = 10)
shelter = patches.Rectangle(((shelter_normalized_x - 5.25/combined_range), (shelter_normalized_y-6.25/combined_range)), 10.5/combined_range,12.5/combined_range,  linewidth = .8, edgecolor = 'none', facecolor = 'blue', alpha = .1)
ax.add_patch(shelter)

ax.set_aspect('equal')
ax.plot(x,y, color = 'blue', linewidth = 1)

# %%
#graphOfHeadAngleVersusDistanceFromShelter(six_second['time_set'].iloc[-1],4, six_second)
